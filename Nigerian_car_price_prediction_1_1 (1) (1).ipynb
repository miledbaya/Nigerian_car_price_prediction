# %% [markdown]
# question1:Load the dataset from the 'Nigerian_Car_Prices.csv' file

# %%
import pandas as pd
file_path = 'Nigerian_Car_Prices.csv'
data = pd.read_csv(file_path)
data
# Out:
#       Unnamed: 0           Make  Year of manufacture      Condition   Mileage  \
# 0              0         Toyota               2007.0  Nigerian Used  166418.0
# 1              1          Lexus                  NaN            NaN  138024.0
# 2              2  Mercedes-Benz               2008.0  Nigerian Used  376807.0
# 3              3          Lexus                  NaN            NaN  213362.0
# 4              4  Mercedes-Benz                  NaN            NaN  106199.0
# ...          ...            ...                  ...            ...       ...
# 4090        4090          Honda               2004.0  Nigerian Used  207446.0
# 4091        4091         Toyota               2005.0  Nigerian Used  106914.0
# 4092        4092          Honda               2006.0  Nigerian Used  247149.0
# 4093        4093         Toyota               2007.0  Nigerian Used  249325.0
# 4094        4094         Toyota               2013.0   Foreign Used  235184.0
#
# ...

# %% [markdown]
# question2:Display the summary statistics of the dataset using the describe() function.

# %%
summary_stats = data.describe()
print(summary_stats)
# Out:
#         Unnamed: 0  Year of manufacture       Mileage    Engine Size
# count  4095.000000          3617.000000  4.024000e+03    3584.000000
# mean   2047.000000          2007.898535  1.825337e+05    3274.976562
# std    1182.269005             4.300126  2.109233e+05    7693.489588
# min       0.000000          1992.000000  1.000000e+00       3.000000
# 25%    1023.500000          2005.000000  1.020640e+05    2000.000000
# 50%    2047.000000          2008.000000  1.613525e+05    2500.000000
# 75%    3070.500000          2011.000000  2.319522e+05    3500.000000
# max    4094.000000          2021.000000  9.976050e+06  371000.000000

# %% [markdown]
# question3:Check the information of the dataset using the info() function.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4095 entries, 0 to 4094
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           4095 non-null   int64
#  1   Make                 4095 non-null   object
#  2   Year of manufacture  3617 non-null   float64
#  3   Condition            3616 non-null   object
#  4   Mileage              4024 non-null   float64
#  5   Engine Size          3584 non-null   float64
#  6   Fuel                 3607 non-null   object
#  7   Transmission         4075 non-null   object
#  8   Price                4095 non-null   object
#  9   Build                1127 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 320.1+ KB

# %% [markdown]
# question4:Preprocess the 'Price' column by removing commas and converting it to a float data type.

# %%
data['Price'] = data['Price'].str.replace(',', '').astype(float)
print (data.head())
# Out:
#    Unnamed: 0           Make  Year of manufacture      Condition   Mileage  \
# 0           0         Toyota               2007.0  Nigerian Used  166418.0
# 1           1          Lexus                  NaN            NaN  138024.0
# 2           2  Mercedes-Benz               2008.0  Nigerian Used  376807.0
# 3           3          Lexus                  NaN            NaN  213362.0
# 4           4  Mercedes-Benz                  NaN            NaN  106199.0
#
#    Engine Size    Fuel Transmission      Price Build
# 0       2400.0  Petrol    Automatic  3120000.0   NaN
# 1          NaN     NaN    Automatic  5834000.0   NaN
# 2       3000.0  Petrol    Automatic  3640000.0   NaN
# 3          NaN     NaN    Automatic  3594000.0   NaN
# 4          NaN     NaN    Automatic  8410000.0   NaN

# %% [markdown]
# question5:Handle missing values, if any, by analyzing and deciding on an appropriate strategy.

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Make                      0
# Year of manufacture     478
# Condition               479
# Mileage                  71
# Engine Size             511
# Fuel                    488
# Transmission             20
# Price                     0
# Build                  2968
# dtype: int64

# %%
data['Year of manufacture'].value_counts()
# Out:
# 2007.0    436
# 2008.0    364
# 2006.0    279
# 2009.0    277
# 2010.0    277
# 2004.0    246
# 2005.0    236
# 2011.0    215
# 2003.0    184
# 2013.0    182
# 2012.0    181
# 2014.0    144
# 2002.0    132
# 2015.0     93
# 2001.0     85
# 2000.0     56
# 2016.0     53
# 1999.0     43
# 2017.0     39
# 2018.0     26
# 1998.0     19
# 1997.0     13
# 2020.0     12
# 2019.0     10
# 1995.0      5
# 1996.0      4
# 2021.0      3
# 1992.0      2
# 1994.0      1
# Name: Year of manufacture, dtype: int64

# %%
data['Year of manufacture']=data['Year of manufacture'].fillna(2007)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Make                      0
# Year of manufacture       0
# Condition               479
# Mileage                  71
# Engine Size             511
# Fuel                    488
# Transmission             20
# Price                     0
# Build                  2968
# dtype: int64

# %%
data['Condition'].value_counts()
# Out:
# Nigerian Used    2521
# Foreign Used     1090
# Brand New           5
# Name: Condition, dtype: int64

# %%
data['Condition']=data['Condition'].fillna('Nigerian Used')

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Make                      0
# Year of manufacture       0
# Condition                 0
# Mileage                  71
# Engine Size             511
# Fuel                    488
# Transmission             20
# Price                     0
# Build                  2968
# dtype: int64

# %%
data['Mileage'].fillna(data['Mileage'].mean(),inplace=True)
data['Engine Size'].fillna(data['Engine Size'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Make                      0
# Year of manufacture       0
# Condition                 0
# Mileage                   0
# Engine Size               0
# Fuel                    488
# Transmission             20
# Price                     0
# Build                  2968
# dtype: int64

# %%
data['Fuel'].value_counts()
# Out:
# Petrol      3535
# Diesel        37
# Hybrid        30
# Electric       5
# Name: Fuel, dtype: int64

# %%
data['Fuel']=data['Fuel'].fillna('Petrol')

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Make                      0
# Year of manufacture       0
# Condition                 0
# Mileage                   0
# Engine Size               0
# Fuel                      0
# Transmission             20
# Price                     0
# Build                  2968
# dtype: int64

# %%
data['Transmission'].value_counts()
# Out:
# Automatic    3810
# Manual        230
# CVT            22
# AMT            13
# Name: Transmission, dtype: int64

# %%
data['Transmission']=data['Transmission'].fillna('Automatic')

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Make                      0
# Year of manufacture       0
# Condition                 0
# Mileage                   0
# Engine Size               0
# Fuel                      0
# Transmission              0
# Price                     0
# Build                  2968
# dtype: int64

# %%
data['Build'].value_counts()
# Out:
# SUV    1127
# Name: Build, dtype: int64

# %%
data['Build']=data['Build'].fillna('SUV')

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# Make                   0
# Year of manufacture    0
# Condition              0
# Mileage                0
# Engine Size            0
# Fuel                   0
# Transmission           0
# Price                  0
# Build                  0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# Make                   0
# Year of manufacture    0
# Condition              0
# Mileage                0
# Engine Size            0
# Fuel                   0
# Transmission           0
# Price                  0
# Build                  0
# dtype: int64

# %% [markdown]
# question6:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'Nigerian_Car_Prices.csv'
data = pd.read_csv(file_path)


plt.figure(figsize=(12, 4))


plt.subplot(1, 3, 1)
sns.histplot(data=data, x='Year of manufacture', bins=20, kde=True)
plt.title('Year of Manufacture')


plt.subplot(1, 3, 2)
sns.histplot(data=data, x='Mileage', bins=20, kde=True)
plt.title('Mileage')


plt.subplot(1, 3, 3)
sns.histplot(data=data, x='Engine Size', bins=20, kde=True)
plt.title('Engine Size')


plt.tight_layout()
plt.show()

# %% [markdown]
# question7:

# %%
mileage_percentile = data['Mileage'].quantile(0.99)


data = data[data['Mileage'] <= mileage_percentile]


print(data.head())
# Out:
#    Unnamed: 0           Make  Year of manufacture      Condition   Mileage  \
# 0           0         Toyota               2007.0  Nigerian Used  166418.0
# 1           1          Lexus                  NaN            NaN  138024.0
# 2           2  Mercedes-Benz               2008.0  Nigerian Used  376807.0
# 3           3          Lexus                  NaN            NaN  213362.0
# 4           4  Mercedes-Benz                  NaN            NaN  106199.0
#
#    Engine Size    Fuel Transmission      Price Build
# 0       2400.0  Petrol    Automatic  3,120,000   NaN
# 1          NaN     NaN    Automatic  5,834,000   NaN
# 2       3000.0  Petrol    Automatic  3,640,000   NaN
# 3          NaN     NaN    Automatic  3,594,000   NaN
# 4          NaN     NaN    Automatic  8,410,000   NaN

# %% [markdown]
# question8:

# %%
plt.figure(figsize=(12, 4))


plt.subplot(1, 3, 1)
sns.scatterplot(data=data, x='Year of manufacture', y='Price')
plt.title('Year of Manufacture vs. Price')


plt.subplot(1, 3, 2)
sns.scatterplot(data=data, x='Mileage', y='Price')
plt.title('Mileage vs. Price')


plt.subplot(1, 3, 3)
sns.scatterplot(data=data, x='Engine Size', y='Price')
plt.title('Engine Size vs. Price')


plt.tight_layout()
plt.show()

# %% [markdown]
# question9:

# %%
import pandas as pd
import numpy as np
data['Price'] = data['Price'].str.replace(',', '').astype(float)

data['log_price'] = np.log(data['Price'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_69164\3731626585.py in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 data['Price'] = data['Price'].str.replace(',', '').astype(float)
#       4
#       5 data['log_price'] = np.log(data['Price'])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
# ...

# %%
data
# Out:
#       Unnamed: 0           Make  Year of manufacture      Condition   Mileage  \
# 0              0         Toyota               2007.0  Nigerian Used  166418.0
# 1              1          Lexus                  NaN            NaN  138024.0
# 2              2  Mercedes-Benz               2008.0  Nigerian Used  376807.0
# 3              3          Lexus                  NaN            NaN  213362.0
# 4              4  Mercedes-Benz                  NaN            NaN  106199.0
# ...          ...            ...                  ...            ...       ...
# 4090        4090          Honda               2004.0  Nigerian Used  207446.0
# 4091        4091         Toyota               2005.0  Nigerian Used  106914.0
# 4092        4092          Honda               2006.0  Nigerian Used  247149.0
# 4093        4093         Toyota               2007.0  Nigerian Used  249325.0
# 4094        4094         Toyota               2013.0   Foreign Used  235184.0
#
# ...

# %%
plt.figure(figsize=(12, 4))


plt.subplot(1, 3, 1)
sns.scatterplot(data=data, x='Year of manufacture', y='log_price')
plt.title('Year of Manufacture vs. log_price')


plt.subplot(1, 3, 2)
sns.scatterplot(data=data, x='Mileage', y='log_price')
plt.title('Mileage vs.log_price')


plt.subplot(1, 3, 3)
sns.scatterplot(data=data, x='Engine Size', y='log_price')
plt.title('Engine Size vs. log_price')


plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 5
#       1 plt.figure(figsize=(12, 4))
#       4 plt.subplot(1, 3, 1)
# ----> 5 sns.scatterplot(data=data, x='Year of manufacture', y='log_price')
#       6 plt.title('Year of Manufacture vs. log_price')
#       9 plt.subplot(1, 3, 2)
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
# ...

# %% [markdown]
# question11:

# %%
plt.figure(figsize=(12, 4))


plt.subplot(1, 3, 1)
sns.histplot(data=data, x='log_price', bins=20, kde=True)
plt.title('log_price')


plt.subplot(1, 3, 2)
sns.histplot(data=data, x='Mileage', bins=20, kde=True)
plt.title('Mileage')


plt.subplot(1, 3, 3)
sns.histplot(data=data, x='Engine Size', bins=20, kde=True)
plt.title('Engine Size')


plt.tight_layout()
plt.show()

# %% [markdown]
# question12:

# %%
plt.figure(figsize=(12, 4))


plt.subplot(1, 3, 1)
sns.scatterplot(data=data, x='Transmission', y='Price')
plt.title('Transmission vs. Price')


plt.subplot(1, 3, 2)
sns.scatterplot(data=data, x='Fuel', y='Price')
plt.title('Fuel vs. Price')


plt.subplot(1, 3, 3)
sns.scatterplot(data=data, x='Condition', y='Price')
plt.title('Condition vs. Price')


plt.tight_layout()
plt.show()

# %% [markdown]
# question13:

# %%
data['Make'].value_counts()
# Out:
# Toyota           1448
# Lexus             453
# Honda             419
# Mercedes-Benz     417
# Ford              193
# Hyundai           173
# Nissan            164
# Kia                89
# Land Rover         70
# Volkswagen         64
# Mazda              63
# BMW                59
# Acura              54
# Infiniti           40
# Chevrolet          39
# Peugeot            31
# Pontiac            22
# Volvo              21
# Mitsubishi         21
# Suzuki             21
# Dodge              15
# Audi               14
# Opel               12
# Jaguar              9
# Jeep                9
# Renault             8
# Chrysler            7
# Porsche             7
# Fiat                6
# GMC                 5
# Lincoln             4
# Changan             4
# Skoda               3
# Citroen             2
# Isuzu               2
# MG                  2
# Hummer              2
# Buick               2
# Mini                2
# JAC                 2
# SsangYong           1
# ...

# %% [markdown]
# question14:

# %%
data = data.drop(columns=['Make'])
data
# Out:
#       Unnamed: 0  Year of manufacture      Condition   Mileage  Engine Size  \
# 0              0               2007.0  Nigerian Used  166418.0       2400.0
# 1              1                  NaN            NaN  138024.0          NaN
# 2              2               2008.0  Nigerian Used  376807.0       3000.0
# 3              3                  NaN            NaN  213362.0          NaN
# 4              4                  NaN            NaN  106199.0          NaN
# ...          ...                  ...            ...       ...          ...
# 4090        4090               2004.0  Nigerian Used  207446.0       3500.0
# 4091        4091               2005.0  Nigerian Used  106914.0       1800.0
# 4092        4092               2006.0  Nigerian Used  247149.0       1800.0
# 4093        4093               2007.0  Nigerian Used  249325.0       2500.0
# 4094        4094               2013.0   Foreign Used  235184.0       2500.0
#
#         Fuel Transmission      Price Build
# ...

# %% [markdown]
# question15:

# %%
data['Build'].fillna('other', inplace=True)
data
# Out:
#       Unnamed: 0  Year of manufacture      Condition   Mileage  Engine Size  \
# 0              0               2007.0  Nigerian Used  166418.0       2400.0
# 1              1                  NaN            NaN  138024.0          NaN
# 2              2               2008.0  Nigerian Used  376807.0       3000.0
# 3              3                  NaN            NaN  213362.0          NaN
# 4              4                  NaN            NaN  106199.0          NaN
# ...          ...                  ...            ...       ...          ...
# 4090        4090               2004.0  Nigerian Used  207446.0       3500.0
# 4091        4091               2005.0  Nigerian Used  106914.0       1800.0
# 4092        4092               2006.0  Nigerian Used  247149.0       1800.0
# 4093        4093               2007.0  Nigerian Used  249325.0       2500.0
# 4094        4094               2013.0   Foreign Used  235184.0       2500.0
#
#         Fuel Transmission      Price  Build
# ...

# %% [markdown]
# qustion1:

# %%
from sklearn.model_selection import train_test_split

# %%
x=data[['Year of manufacture','Condition','Mileage','Engine Size','Fuel','Transmission','Build']]
y=data['Price']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(X_train, X_test)
print(y_train, y_test)
# Out:
#       Year of manufacture      Condition   Mileage  Engine Size    Fuel  \
# 568                2012.0  Nigerian Used   69388.0       3500.0  Petrol
# 1624               2008.0  Nigerian Used  151790.0       3000.0  Petrol
# 615                2012.0   Foreign Used  201267.0       3500.0  Petrol
# 451                   NaN            NaN  144059.0          NaN     NaN
# 1819               2008.0  Nigerian Used  253998.0       2400.0  Petrol
# ...                   ...            ...       ...          ...     ...
# 1161               2005.0  Nigerian Used   98692.0       2400.0  Petrol
# 1330               2008.0   Foreign Used  166063.0       2400.0  Petrol
# 875                2010.0   Foreign Used  315836.0       3500.0  Petrol
# 3598               2002.0   Foreign Used  295860.0          NaN  Petrol
# 3253                  NaN            NaN  187762.0          NaN     NaN
#
#      Transmission  Build
# 568     Automatic  other
# 1624    Automatic  other
# ...

# %% [markdown]
# question2:

# %%
X = data.drop(['Price'], axis=1)
y = data['Price']
cat = [cname for cname in X.columns if X[cname].dtype == 'object']
num = [cname for cname in X.columns if X[cname].dtype == 'float64' or X[cname].dtype=='int64']

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
cat_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # Impute missing values with most frequent value
    ('onehot', OneHotEncoder(handle_unknown='ignore'))  # Use one-hot encoding
])

# %%
from sklearn.preprocessing import MinMaxScaler
num_pipeline = Pipeline(steps=[
    ('scaler', MinMaxScaler())  # Use MinMaxScaler for scaling
])

# %%
from sklearn.compose import ColumnTransformer
numerical_cols=['Year of manufacture','Mileage','Engine Size']
categorical_cols=['Condition','Fuel','Transmission']
full_pipeline = ColumnTransformer(
    transformers=[
        ('num', num_pipeline, numerical_cols),
        ('cat', cat_pipeline, categorical_cols)
    ]
)
X_train_preprocessed = full_pipeline.fit_transform(X_train)

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
models=[
    ('sgd',SGDRegressor()),
    ('svr',SVR()),
    ('ran',RandomForestRegressor()),
    ('ada',AdaBoostRegressor()),
    ('bag',BaggingRegressor()),
    ('extra',ExtraTreesRegressor()),
    ('grad',GradientBoostingRegressor()),
    ('xgbr',XGBRegressor())
    
]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_squared_error
import numpy as np

# %%
rmse_scores = {}

for model_name, model in models:
    scores=cross_val_score(model, X_train_preprocessed, y_train, scoring="neg_mean_squared_error", cv=5)
    rmse_scores= np.sqrt(-scores.mean())
    print(model_name,rmse_scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 4
#       1 rmse_scores = {}
#       3 for model_name, model in models:
# ----> 4     scores=cross_val_score(model, X_train_preprocessed, y_train, scoring="neg_mean_squared_error", cv=5)
#       5     rmse_scores= np.sqrt(-scores.mean())
#       6     print(model_name,rmse_scores)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
# ...

# %%
for model_name, rmse in rmse_scores.items():
    print(f"{model_name}: RMSE = {rmse:.2f}")
